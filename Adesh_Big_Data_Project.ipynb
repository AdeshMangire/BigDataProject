# %% [markdown]
# ## Project Name

# %% [markdown]
# ### Importing libraries:
#
# We are importing libraries for Analysing the data. It includes:
#
# 1. pandas
# 2. numpy
# 3. matplotlib
# 4. seaborn

# %%
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import seaborn as sns

# %%
df = pd.read_csv("D:/archive/1429_1.csv")
df.head()
# Out:
# C:\Users\Aadesh\AppData\Local\Temp\ipykernel_15100\3498720265.py:1: DtypeWarning: Columns (1,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("D:/archive/1429_1.csv")
#                      id                                               name  \
# 0  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 1  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 3  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 4  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#         asins   brand                                         categories  \
# 0  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34660 entries, 0 to 34659
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    34660 non-null  object
#  1   name                  27900 non-null  object
#  2   asins                 34658 non-null  object
#  3   brand                 34660 non-null  object
#  4   categories            34660 non-null  object
#  5   keys                  34660 non-null  object
#  6   manufacturer          34660 non-null  object
#  7   reviews.date          34621 non-null  object
#  8   reviews.dateAdded     24039 non-null  object
#  9   reviews.dateSeen      34660 non-null  object
#  10  reviews.didPurchase   1 non-null      object
#  11  reviews.doRecommend   34066 non-null  object
#  12  reviews.id            1 non-null      float64
#  13  reviews.numHelpful    34131 non-null  float64
#  14  reviews.rating        34627 non-null  float64
# ...

# %%
data = df[["reviews.text", "reviews.rating"]]
data.head()
# Out:
#                                         reviews.text  reviews.rating
# 0  This product so far has not disappointed. My c...             5.0
# 1  great for beginner or experienced person. Boug...             5.0
# 2  Inexpensive tablet for him to use and learn on...             5.0
# 3  I've had my Fire HD 8 two weeks now and I love...             4.0
# 4  I bought this for my grand daughter when she c...             5.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34660 entries, 0 to 34659
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   reviews.text    34659 non-null  object
#  1   reviews.rating  34627 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 541.7+ KB

# %%
#drop null values
data.dropna(inplace=True)
data.isnull().sum()
# Out:
# C:\Users\Aadesh\AppData\Local\Temp\ipykernel_15100\4210551023.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)
# reviews.text      0
# reviews.rating    0
# dtype: int64

# %%
import random
n_samples = 5

for _ in range(n_samples):
    i = random.choice(range(data.shape[0]))
    print(f"REVIEW TEXT:\n{data['reviews.text'][i]} \n\nRATE:\n{data['reviews.rating'][i]}")
    print('\n', 90*"-", '\n')
# Out:
# REVIEW TEXT:
# gift for mom,perfect for her enjoyment,good picture
#
# RATE:
# 4.0
#
#  ------------------------------------------------------------------------------------------
#
# REVIEW TEXT:
# This is a neat little device but really not that good for much. I am sure it will improve in the future but I would recommend waiting it out.
#
# RATE:
# 3.0
#
#  ------------------------------------------------------------------------------------------
#
# REVIEW TEXT:
# This is not recommended if you have inpatient kids.
#
# RATE:
# 3.0
#
#  ------------------------------------------------------------------------------------------
#
# REVIEW TEXT:
# This tablet is great for ebooks and small apps. Kid friendly.I feel like it runs slower than apple products. But can't beat the price overall.
#
# RATE:
# 4.0
#
#  ------------------------------------------------------------------------------------------
#
# REVIEW TEXT:
# ...

# %%
# descriptive statistics
data.describe()
# Out:
#        reviews.rating
# count    34626.000000
# mean         4.584561
# std          0.735660
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000

# %%
# distribution of rating
data['reviews.rating'].value_counts().sort_index(ascending=False)
# Out:
# reviews.rating
# 5.0    23774
# 4.0     8541
# 3.0     1499
# 2.0      402
# 1.0      410
# Name: count, dtype: int64

# %%
rating = data["reviews.rating"].value_counts
rating
# Out:
# <bound method IndexOpsMixin.value_counts of 0        5.0
# 1        5.0
# 2        5.0
# 3        4.0
# 4        5.0
#         ...
# 34655    3.0
# 34656    1.0
# 34657    1.0
# 34658    1.0
# 34659    1.0
# Name: reviews.rating, Length: 34626, dtype: float64>

# %%
# distribution of rating
sns.countplot(x = data['reviews.rating'], palette='Blues')

plt.title('Distribution of rating scores')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Aadesh\AppData\Local\Temp\ipykernel_15100\2890151192.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = data['reviews.rating'], palette='Blues')

# %% [markdown]
# The given data has less ammount of bad rating reviews. for better training we'll need more data for the purpose
# filtering and importing low ratings from the data.

# %%
# loading new data
data_2 = pd.read_csv("D:/archive/Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products_May19.csv")
data_2 = data_2[["reviews.text", "reviews.rating"]]

# using only lower ratings. less than or equals 3
data_2 = data_2[data_2["reviews.rating"] <= 3].reset_index(drop=True)

#now for 3rd Dataset as well
data_3 = pd.read_csv("D:/archive/Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products.csv")
data_3 = data_3[["reviews.text", "reviews.rating"]]
data_3 = data_3[data_3["reviews.rating"] <=3 ].reset_index(drop=True)

# %%
data_2["reviews.rating"].value_counts().sort_index(ascending=False)
# Out:
# reviews.rating
# 3    1206
# 2     616
# 1     965
# Name: count, dtype: int64

# %%
data_3["reviews.rating"].value_counts().sort_index(ascending=False)
# Out:
# reviews.rating
# 3    197
# 2     54
# 1     63
# Name: count, dtype: int64

# %%
#concatination
data = pd.concat([data, data_2, data_3])

data.head()
# Out:
#                                         reviews.text  reviews.rating
# 0  This product so far has not disappointed. My c...             5.0
# 1  great for beginner or experienced person. Boug...             5.0
# 2  Inexpensive tablet for him to use and learn on...             5.0
# 3  I've had my Fire HD 8 two weeks now and I love...             4.0
# 4  I bought this for my grand daughter when she c...             5.0

# %%
data["reviews.rating"].value_counts().sort_index(ascending=False)
# Out:
# reviews.rating
# 5.0    23774
# 4.0     8541
# 3.0     2902
# 2.0     1072
# 1.0     1438
# Name: count, dtype: int64

# %%
# distribution of rating
sns.countplot(x = data['reviews.rating'], palette='Blues')

plt.title('Distribution of rating scores')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Aadesh\AppData\Local\Temp\ipykernel_15100\2890151192.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = data['reviews.rating'], palette='Blues')

# %%
# we'll map ratings.

sentiment_score = {1: 0,
                   2: 0,
                   3: 0,
                   4: 1,
                   5: 1}
sentiment = {0: 'NEGATIVE',
             1: 'POSITIVE'}
data['sentiment_score'] = data ['reviews.rating'].map(sentiment_score)
data['sentiment'] = data['sentiment_score'].map(sentiment)

# %%
data.head()
# Out:
#                                         reviews.text  reviews.rating  \
# 0  This product so far has not disappointed. My c...             5.0
# 1  great for beginner or experienced person. Boug...             5.0
# 2  Inexpensive tablet for him to use and learn on...             5.0
# 3  I've had my Fire HD 8 two weeks now and I love...             4.0
# 4  I bought this for my grand daughter when she c...             5.0
#
#    sentiment_score sentiment
# 0                1  POSITIVE
# 1                1  POSITIVE
# 2                1  POSITIVE
# 3                1  POSITIVE
# 4                1  POSITIVE

# %%
import pandas as pd 

data.to_csv('sentiment_score.csv',index=False)

# %%
plt.figure(figsize = (5,5))

labels = ['POSITIVE', 'NEGATIVE']
colors = colors = ['#355E3B', '#DC143C']

plt.pie(data['sentiment'].value_counts(), autopct='%0.2f%%',colors=colors)

plt.title('Distribution of sentiment', size=14, y=-0.01)
plt.legend(labels, ncol=2, loc=9)
plt.show()

# %%
# getting all used words
all_words = pd.Series(' '.join(data['reviews.text']).split())

# %%
#!pip install wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
# plotting word cloud

wordcloud = WordCloud(width = 1000, height = 500).generate(''.join(all_words))

plt.figure(figsize = (15,8) )
plt.imshow(wordcloud)
plt.title ('most used words in the text data')

plt.show()

# %% [markdown]
# # Predictions

# %% [markdown]
# ### Data Preprocessing
# ensuring if the data is ready for vectorization and model training.
#
# This includes splitting the data into training and testing datasets.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data['reviews.text'], data['sentiment'], test_size=0.2, random_state=42)

# %% [markdown]
# ### Vectorization of Text Data

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Using a common technique TF-IDF vectorization, to convert text data into a numeric form that machine learning algorithms can process.
vectorizer = TfidfVectorizer(max_features=5000)
X_train_vect = vectorizer.fit_transform(X_train)
X_test_vect = vectorizer.transform(X_test)

# %% [markdown]
# ### Model Training
# we'll train three different models and compare their initial performances.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.metrics import classification_report

# Logistic Regression
lr_model = LogisticRegression(random_state=42)
lr_model.fit(X_train_vect, y_train)
y_pred_lr = lr_model.predict(X_test_vect)
print("Logistic Regression Results:")
print(classification_report(y_test, y_pred_lr))

# Naive Bayes
nb_model = MultinomialNB()
nb_model.fit(X_train_vect, y_train)
y_pred_nb = nb_model.predict(X_test_vect)
print("Naive Bayes Results:")
print(classification_report(y_test, y_pred_nb))

# Support Vector Machine
svm_model = SVC(random_state=42)
svm_model.fit(X_train_vect, y_train)
y_pred_svm = svm_model.predict(X_test_vect)
print("SVM Results:")
print(classification_report(y_test, y_pred_svm))
# Out:
# C:\Users\Aadesh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#     NEGATIVE       0.84      0.57      0.68      1106
#     POSITIVE       0.93      0.98      0.95      6440
#
#     accuracy                           0.92      7546
#    macro avg       0.89      0.77      0.82      7546
# weighted avg       0.92      0.92      0.91      7546
#
# ...

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ### Report: Evaluation of Sentiment Analysis Models
#
# #### Introduction
# This report analyzes the performance of three machine learning models—Logistic Regression, Naive Bayes, and Support Vector Machines (SVM)—in classifying text data into positive and negative sentiments.
#
# #### Metrics Explained
# - **Precision**: Measures the accuracy of positive predictions.
# - **Recall**: Measures the model’s ability to identify all relevant instances.
# - **F1-Score**: Harmonic mean of precision and recall.
# - **Accuracy**: Proportion of correct predictions.
# - **Macro Average**: Averages the metric independently for each class.
# - **Weighted Average**: Averages the metric for each class, weighted by the number of true instances.
#
# #### Model Performance Analysis
#
# ##### Logistic Regression Results
# - **Precision**: NEGATIVE (0.84), POSITIVE (0.93)
# - **Recall**: NEGATIVE (0.57), POSITIVE (0.98)
# - **F1-Score**: NEGATIVE (0.68), POSITIVE (0.95)
# - **Overall Accuracy**: 92%
#
# ##### Naive Bayes Results
# - **Precision**: NEGATIVE (0.94), POSITIVE (0.91)
# - **Recall**: NEGATIVE (0.40), POSITIVE (1.00)
# - **F1-Score**: NEGATIVE (0.56), POSITIVE (0.95)
# - **Overall Accuracy**: 91%
#
# ##### SVM Results
# - **Precision**: NEGATIVE (0.93), POSITIVE (0.95)
# - **Recall**: NEGATIVE (0.68), POSITIVE (0.99)
# - **F1-Score**: NEGATIVE (0.78), POSITIVE (0.97)
# - **Overall Accuracy**: 94%
#
# #### Insights and Interpretations
#
# 1. **Model Comparison**:
#    - **Logistic Regression** offers a balance between precision and recall but falls short in identifying negative sentiments as effectively as the SVM.
#    - **Naive Bayes** shows high precision for negative sentiments but significantly lacks in recall, indicating it misses many actual negative instances.
#    - **SVM** demonstrates the highest balance and performance across both recall and precision, particularly excelling in the negative class compared to the other models.
#
# 2. **Performance Implications**:
#    - **SVM** is the most robust model for this particular task, especially in an imbalanced dataset context.
#    - **Logistic Regression** provides a reasonable compromise and might benefit from further parameter tuning or additional feature engineering.
#    - **Naive Bayes** might not be ideal when high recall for the negative class is critical unless adjustments to its handling of class imbalance are made.
#
# #### Recommendations
# - **Explore Advanced Techniques**: Advanced text processing and model-specific tuning can improve performance.
# - **Experiment with Resampling**: Addressing class imbalance directly through synthetic data generation or resampling strategies might boost the underperforming recall in some models.
# - **Model Ensembles**: Combining the strengths of different models through techniques like stacking might improve both precision and recall.
#
# #### Conclusion
# Each model has its strengths and weaknesses, and the choice of model can depend on the specific requirements of sentiment classification tasks. The SVM stands out in handling both classes effectively under the current setup and is recommended for scenarios where high accuracy across both sentiment polarities is crucial. Further investigations into feature engineering, model tuning, and potentially ensembling different models could yield even better results.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_fscore_support

# Compute the performance metrics for each model
metrics_lr = precision_recall_fscore_support(y_test, y_pred_lr, average='weighted')
metrics_nb = precision_recall_fscore_support(y_test, y_pred_nb, average='weighted')
metrics_svm = precision_recall_fscore_support(y_test, y_pred_svm, average='weighted')

# Aggregate the metrics
precision = [metrics_lr[0], metrics_nb[0], metrics_svm[0]]
recall = [metrics_lr[1], metrics_nb[1], metrics_svm[1]]
f1_score = [metrics_lr[2], metrics_nb[2], metrics_svm[2]]

# Set up the bar plot
n_groups = 3
index = np.arange(n_groups)
bar_width = 0.2

# Create the bar plot
fig, ax = plt.subplots()
bar1 = ax.bar(index, precision, bar_width, label='Precision')
bar2 = ax.bar(index + bar_width, recall, bar_width, label='Recall')
bar3 = ax.bar(index + bar_width * 2, f1_score, bar_width, label='F1 Score')

# Add labels, title, and legend
ax.set_xlabel('Models')
ax.set_ylabel('Scores')
ax.set_title('Comparison of Model Performance')
ax.set_xticks(index + bar_width)
ax.set_xticklabels(['Logistic Regression', 'Naive Bayes', 'SVM'])
ax.legend()

# Show the plot
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Compute confusion matrices for each model
cm_lr = confusion_matrix(y_test, y_pred_lr)
cm_nb = confusion_matrix(y_test, y_pred_nb)
cm_svm = confusion_matrix(y_test, y_pred_svm)

# Define a function to plot confusion matrix
def plot_confusion_matrix(cm, model_name, ax):
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax)
    ax.set_title(f'Confusion Matrix for {model_name}')
    ax.set_xlabel('Predicted labels')
    ax.set_ylabel('True labels')
    ax.set_xticklabels(['Negative', 'Positive'])
    ax.set_yticklabels(['Negative', 'Positive'])

# Set up matplotlib figure and axes
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Plot each confusion matrix
plot_confusion_matrix(cm_lr, 'Logistic Regression', axes[0])
plot_confusion_matrix(cm_nb, 'Naive Bayes', axes[1])
plot_confusion_matrix(cm_svm, 'SVM', axes[2])

# Adjust the layout
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Assuming these are your model predictions
y_prob_lr = lr_model.predict_proba(X_test_vect)[:, 1]
y_prob_nb = nb_model.predict_proba(X_test_vect)[:, 1]
y_score_svm = svm_model.decision_function(X_test_vect)  # Corrected variable name here

# Calculate ROC curve and ROC area for each class
fpr_lr, tpr_lr, _ = roc_curve(y_test, y_prob_lr, pos_label='POSITIVE')
roc_auc_lr = auc(fpr_lr, tpr_lr)

fpr_nb, tpr_nb, _ = roc_curve(y_test, y_prob_nb, pos_label='POSITIVE')
roc_auc_nb = auc(fpr_nb, tpr_nb)

# For SVM, we use the decision function if it was not trained with probability estimates
fpr_svm, tpr_svm, _ = roc_curve(y_test, y_score_svm, pos_label='POSITIVE')
roc_auc_svm = auc(fpr_svm, tpr_svm)

# Plot all ROC curves
plt.figure()
plt.plot(fpr_lr, tpr_lr, color='orange', lw=2, label='ROC curve for LR (area = %0.2f)' % roc_auc_lr)
plt.plot(fpr_nb, tpr_nb, color='green', lw=2, label='ROC curve for NB (area = %0.2f)' % roc_auc_nb)
plt.plot(fpr_svm, tpr_svm, color='blue', lw=2, label='ROC curve for SVM (area = %0.2f)' % roc_auc_svm)

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
import matplotlib.pyplot as plt

# Map true labels to binary
y_test_binary = y_test.map({'NEGATIVE': 0, 'POSITIVE': 1})

# Create histograms
plt.figure(figsize=(14, 6))

plt.subplot(1, 3, 1)
plt.hist(y_prob_lr[y_test_binary == 0], bins=50, alpha=0.5, label='NEGATIVE')
plt.hist(y_prob_lr[y_test_binary == 1], bins=50, alpha=0.5, label='POSITIVE')
plt.title('Logistic Regression Probabilities')
plt.xlabel('Predicted probability')
plt.ylabel('Frequency')
plt.legend()

plt.subplot(1, 3, 2)
plt.hist(y_prob_nb[y_test_binary == 0], bins=50, alpha=0.5, label='NEGATIVE')
plt.hist(y_prob_nb[y_test_binary == 1], bins=50, alpha=0.5, label='POSITIVE')
plt.title('Naive Bayes Probabilities')
plt.xlabel('Predicted probability')
plt.ylabel('Frequency')
plt.legend()

min_score = min(y_score_svm)
max_score = max(y_score_svm)
y_prob_svm_scaled = (y_score_svm - min_score) / (max_score - min_score)

plt.subplot(1, 3, 3)
plt.hist(y_prob_svm_scaled[y_test_binary == 0], bins=50, alpha=0.5, label='NEGATIVE')
plt.hist(y_prob_svm_scaled[y_test_binary == 1], bins=50, alpha=0.5, label='POSITIVE')
plt.title('SVM Probabilities (Scaled)')
plt.xlabel('Predicted probability')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import learning_curve
import numpy as np
import matplotlib.pyplot as plt

def plot_learning_curve(estimator, title, X, y, axes=None, ylim=None, cv=None,
                        n_jobs=None, train_sizes=np.linspace(0.1, 1.0, 5)):
    
    if axes is None:
        _, axes = plt.subplots(1, 1, figsize=(20, 5))

    axes.set_title(title)
    if ylim is not None:
        axes.set_ylim(*ylim)
    axes.set_xlabel("Training examples")
    axes.set_ylabel("Score")

    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes,
        scoring="accuracy", shuffle=True)

    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)

    # Plot learning curve
    axes.grid()
    axes.fill_between(train_sizes, train_scores_mean - train_scores_std,
                      train_scores_mean + train_scores_std, color="gray", alpha=0.1)
    axes.fill_between(train_sizes, test_scores_mean - test_scores_std,
                      test_scores_mean + test_scores_std, color="gray", alpha=0.1)
    axes.plot(train_sizes, train_scores_mean, 'o-', color="r",
              label="Training score")
    axes.plot(train_sizes, test_scores_mean, 'o-', color="g",
              label="Cross-validation score")
    axes.legend(loc="best")

    return plt

fig, axes = plt.subplots(3, 1, figsize=(10, 15))

X, y = X_train_vect, y_train  # Assuming X_train_vect and y_train are defined

# Plot learning curve for Logistic Regression
plot_learning_curve(lr_model, "Learning Curve (Logistic Regression)", X, y, axes=axes[0], ylim=(0.7, 1.01), cv=5, n_jobs=4)

# Plot learning curve for Naive Bayes
plot_learning_curve(nb_model, "Learning Curve (Naive Bayes)", X, y, axes=axes[1], ylim=(0.7, 1.01), cv=5, n_jobs=4)

# Plot learning curve for SVM
plot_learning_curve(svm_model, "Learning Curve (SVM)", X, y, axes=axes[2], ylim=(0.7, 1.01), cv=5, n_jobs=4)

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()
